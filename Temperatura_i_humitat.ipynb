# %% [markdown]
# <a href="https://colab.research.google.com/github/ZhezhengMVM/BTX/blob/main/Temperatura_i_humitat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
csv_temperatura = pd.read_csv('Activitat 4. Temperatura - Full 1.csv')
csv_temperatura
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1bd47739eb75> in <cell line: 0>()
# ----> 1 csv_temperatura = pd.read_csv('Activitat 4. Temperatura - Full 1.csv')
#       2 csv_temperatura
#
# NameError: name 'pd' is not defined

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (s)']
  ys = series['A-14']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv_temperatura.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (s)')
_ = plt.ylabel('Temperatura A-14')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (s)']
  ys = series['A-23']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv_temperatura.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (s)')
_ = plt.ylabel('Temperatura A-23')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (s)']
  ys = series['Laboratori']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv_temperatura.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (s)')
_ = plt.ylabel('Temperatura laboratori')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (s)']
  ys = series['Passadís']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv_temperatura.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (s)')
_ = plt.ylabel('Temperatura passadís')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (s)']
  ys = series['Pati']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv_temperatura.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (s)')
_ = plt.ylabel('Temperatura pati')

# %%
csv_humitat = pd.read_csv('Activitat 4. Humitat - Full 1.csv')
csv_humitat
# Out:
#      Temps (s)  A-14  A-23  Laboratori  Passadís  Pati
# 0            1    38    37          37        32    23
# 1            2    38    37          37        32    23
# 2            3    38    37          37        32    23
# 3            4    39    38          37        32    23
# 4            5    38    37          37        32    23
# ..         ...   ...   ...         ...       ...   ...
# 175        176    39    37          38        33    17
# 176        177    39    38          38        33    17
# 177        178    39    37          38        33    17
# 178        179    39    37          38        33    17
# 179        180    39    37          38        33    17
#
# [180 rows x 6 columns]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (s)']
  ys = series['A-14']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv_humitat.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (s)')
_ = plt.ylabel('Humitat A-14')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (s)']
  ys = series['A-23']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv_humitat.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (s)')
_ = plt.ylabel('Humitat A-23')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (s)']
  ys = series['Laboratori']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv_humitat.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (s)')
_ = plt.ylabel('Humitat laboratori')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (s)']
  ys = series['Passadís']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv_humitat.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (s)')
_ = plt.ylabel('Humitat passadís')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (s)']
  ys = series['Pati']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv_humitat.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (s)')
_ = plt.ylabel('Humitat pati')

# %%
max1 = csv_humitat['A-14'].max()
min1 = csv_humitat['A-14'].min()
mitjana1 = round(csv_humitat['A-14'].mean(), 2)

print(f"El màxim de humitat de l'aula-14 és {max1}")
print(f"El mínim de humitat de l'aula-14 és {min1}")
print(f"La mitjana de humitat de l'aula-14 és {mitjana1}\n")


max2 = csv_humitat['A-23'].max()
min2 = csv_humitat['A-23'].min()
mitjana2 = round(csv_humitat['A-23'].mean(), 2)

print(f"El màxim de humitat de l'aula-23 és {max2}")
print(f"El mínim de humitat de l'aula-23 és {min2}")
print(f"La mitjana de humitat de l'aula-23 és {mitjana2}\n")


max3 = csv_humitat['Laboratori'].max()
min3 = csv_humitat['Laboratori'].min()
mitjana3 = round(csv_humitat['Laboratori'].mean(), 2)

print(f"El màxim de humitat del laboratori és {max3}")
print(f"El mínim de humitat del laboratori és {min3}")
print(f"La mitjana de humitat de laboratori és {mitjana3}\n")

max4 = csv_humitat['Passadís'].max()
min4 = csv_humitat['Passadís'].min()
mitjana4 = round(csv_humitat['Passadís'].mean(), 2)

print(f"El màxim de humitat del passadís és {max4}")
print(f"El mínim de humitat del passadís és {min4}")
print(f"La mitjana de humitat de passadís és {mitjana4}\n")

max5 = csv_humitat['Pati'].max()
min5 = csv_humitat['Pati'].min()
mitjana5 = round(csv_humitat['Pati'].mean(), 2)

print(f"El màxim de humitat del pati és {max5}")
print(f"El mínim de humitat del pati és {min5}")
print(f"La mitjana de humitat de pati és {mitjana5}\n")
# Out:
# El màxim de humitat de l'aula-14 és 39
# El mínim de humitat de l'aula-14 és 38
# La mitjana de humitat de l'aula-14 és 38.49
#
# El màxim de humitat de l'aula-23 és 38
# El mínim de humitat de l'aula-23 és 37
# La mitjana de humitat de l'aula-23 és 37.52
#
# El màxim de humitat del laboratori és 38
# El mínim de humitat del laboratori és 37
# La mitjana de humitat de laboratori és 37.49
#
# El màxim de humitat del passadís és 33
# El mínim de humitat del passadís és 32
# La mitjana de humitat de passadís és 32.29
#
# El màxim de humitat del pati és 23
# El mínim de humitat del pati és 17
# La mitjana de humitat de pati és 20.02
