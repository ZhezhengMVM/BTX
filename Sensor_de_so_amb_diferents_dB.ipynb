# %% [markdown]
# <a href="https://colab.research.google.com/github/ZhezhengMVM/BTX/blob/main/Sensor_de_so_amb_diferents_dB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

csv = pd.read_csv('Microbit - Nivell de so amb diferents dB - Full 1.csv')
csv
# Out:
#      Temps (segons)  Aula-14  Aula-23  Passadís
# 0                 1       37       52        26
# 1                 2       26       63        45
# 2                 3       52       18        37
# 3                 4       32       18       112
# 4                 5       45       18        67
# ..              ...      ...      ...       ...
# 175             176       33       22        26
# 176             177       52       26        94
# 177             178       37       33        33
# 178             179       30       52        30
# 179             180       56       37        22
#
# [180 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# csv['Temps (segons)'].plot(kind='hist', bins=20, title='Temps (segons)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (segons)']
  ys = series['Aula-14']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (segons)')
_ = plt.ylabel('Aula-14')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (segons)']
  ys = series['Aula-23']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (segons)')
_ = plt.ylabel('Aula-23')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (segons)']
  ys = series['Passadís']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (segons)')
_ = plt.ylabel('Passadís')

# %%
max1 = csv['Aula-14'].max()
min1 = csv['Aula-14'].min()
mitjana1 = csv['Aula-14'].sum()/len(csv['Aula-14'])

print(f"El màxim de l'aula'14 és {max1}")
print(f"El mínim de l'aula'14 és {min1}")
print(f"La mitjana de l'aula'14 és {round(mitjana1, 2)}")
print() #Salt de línia per veure els outputs més clrars


max2 = csv['Aula-23'].max()
min2 = csv['Aula-23'].min()
mitjana2 = csv['Aula-23'].sum()/len(csv['Aula-23'])

print(f"El màxim de l'aula-23 és {max2}")
print(f"El mínim de l'aula-23 és {min2}")
print(f"La mitjana de l'aula-23 és {round(mitjana2, 2)}")
print()


max2 = csv['Passadís'].max()
min2 = csv['Passadís'].min()
mitjana2 = csv['Passadís'].sum()/len(csv['Passadís'])

print(f"El màxim del passadís és {max2}")
print(f"El mínim del passadís és {min2}")
print(f"La mitjana del passadís és {round(mitjana2, 2)}")
# Out:
# El màxim de l'aula'14 és 67
# El mínim de l'aula'14 és 7
# La mitjana de l'aula'14 és 29.977777777777778
#
# El màxim de l'aula-23 és 78
# El mínim de l'aula-23 és 7
# La mitjana de l'aula-23 és 30.055555555555557
#
# El màxim del passadís és 114
# El mínim del passadís és 15
# La mitjana del passadís és 40.55
