# %% [markdown]
# <a href="https://colab.research.google.com/github/ZhezhengMVM/BTX/blob/main/Sensor_de_llum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

csv = pd.read_csv('Microbit - Lluminanositat - Full 1.csv')
csv
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-4b3279d56738> in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 csv = pd.read_csv('Microbit - Lluminanositat - Full 1.csv')
#       4 csv
#
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (segons)']
  ys = series['Aula-14']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (segons)')
_ = plt.ylabel('Aula-14')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (segons)']
  ys = series['Taula de ping-pong']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (segons)')
_ = plt.ylabel('Taula de ping-pong')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temps (segons)']
  ys = series['Pati']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = csv.sort_values('Temps (segons)', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temps (segons)')
_ = plt.ylabel('Pati')

# %%
max1 = csv['Aula-14'].max()
min1 = csv['Aula-14'].min()
mitjana1 = csv['Aula-14'].sum()/len(csv['Aula-14'])

print(f"El màxim de l'aula-14 és {max1}")
print(f"El mínim de l'aula-14 és {min1}")
print(f"La mitjana de l'aula-14 és {round(mitjana1, 2)}")
print() #Salt de línia per veure la sortida més clrars


max2 = csv['Taula de ping-pong'].max()
min2 = csv['Taula de ping-pong'].min()
mitjana2 = csv['Taula de ping-pong'].sum()/len(csv['Taula de ping-pong'])

print(f"El màxim de la taula de ping-pong és {max2}")
print(f"El mínim de la taula de ping-pong és {min2}")
print(f"La mitjana de la taula de ping-pong és {round(mitjana2, 2)}")
print()


max2 = csv['Pati'].max()
min2 = csv['Pati'].min()
mitjana2 = csv['Pati'].sum()/len(csv['Pati'])

print(f"El màxim del pati és {max2}")
print(f"El mínim del pati és {min2}")
print(f"La mitjana del pati és {round(mitjana2, 2)}")
# Out:
# El màxim de l'aula-14 és 196
# El mínim de l'aula-14 és 124
# La mitjana de l'aula-14 és 172.40555555555557
#
# El màxim de la taula de ping-pong és 247
# El mínim de la taula de ping-pong és 243
# La mitjana de la taula de ping-pong és 245.98333333333332
#
# El màxim del pati és 254
# El mínim del pati és 253
# La mitjana del pati és 253.8
